# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2
import seaborn as sbn
import matplotlib.gridspec as gridspec
from matplotlib import cm
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# query = """ 
#     select dq.event_date, c.label, dq.close_value
#     from company c
#     inner join daily_quote dq on c.id = dq.company_id
#     where c.label in (
#          'ITSA3', 'EGIE3', 'ITUB3', 'BRSR6', 'FESA4', 'ABCB4', 'ENBR3', 'GRND3', 'FRAS3', 'CSAN3')
#     and (now() - dq.event_date) <= interval '3 months'
#     order by dq.event_date;"""
query = """ 
    select dq.event_date, c.label, dq.close_value
    from company c
    inner join daily_quote dq on c.id = dq.company_id
    where c.label in (
         'MPLU3', 'EQTL3', 'ITSA3', 'BBDC4', 'ABCB4', 'FESA4', 'NATU3', 'FRAS3', 'UNIP3', 'ITUB3', 'TRPL4', 'SAPR4', 'ENBR3', 'EGIE3', 'RENT3', 'CMIG4', 'CSNA3', 'PCAR4', 'CYRE3', 'PTBL3')
    and (now() - dq.event_date) <= interval '4.5 months'     
    order by dq.event_date;"""

# %%
conn = psycopg2.connect(
            database="postgres",
            user="postgres",
            connect_timeout=3,
            options='-c statement_timeout=3000')
raw_df = pd.read_sql(query, conn)
conn.close()

# %%
raw_df.columns = ['Data', 'Sigla', 'VF']
raw_df.set_index(['Data', 'Sigla'], inplace=True)

# %%
df = (raw_df.unstack()
      .replace({0: np.NaN})
      .fillna(method='ffill'))
df.tail()
# Out:
#                VF                                                          \
# Sigla       ABCB4  BBDC4  CMIG4  CSNA3  CYRE3  EGIE3  ENBR3  EQTL3  FESA4
# Data
# 2019-02-25  18.39  44.15  14.26  13.10  17.06  42.11  18.54  83.99  27.26
# 2019-02-26  18.45  44.94  14.35  13.19  17.01  41.48  18.03  83.61  27.04
# 2019-02-27  18.32  44.44  14.69  12.68  17.46  42.10  18.61  82.98  27.28
# 2019-02-28  18.28  43.27  14.40  13.08  17.10  41.16  17.30  82.13  27.40
# 2019-03-01  18.27  42.55  14.06  13.85  16.95  40.36  17.46  82.47  27.01
#
#                                                                          \
# Sigla      FRAS3  ITSA3  ITUB3  MPLU3  NATU3  PCAR4 PTBL3  RENT3  SAPR4
# Data
# 2019-02-25  4.98  15.41  31.60  26.51  49.87  95.84  5.31  34.84  14.39
# 2019-02-26  4.96  15.21  31.55  26.50  49.10  94.80  5.30  35.10  14.12
# 2019-02-27  5.07  15.30  31.45  26.46  48.20  94.08  5.26  34.61  14.16
# 2019-02-28  5.01  15.00  31.11  26.67  48.38  93.11  5.20  34.55  13.68
# 2019-03-01  5.05  14.97  30.75  26.60  47.50  93.45  5.10  33.60  13.56
#
#
# Sigla       TRPL4  UNIP3
# Data
# 2019-02-25  77.63  39.70
# 2019-02-26  77.13  39.85
# 2019-02-27  78.00  39.40
# 2019-02-28  77.20  39.49
# 2019-03-01  79.50  39.20

# %%
df = df['VF']

# %%
columns = pd.Series(df.columns.values)

# %%
row = 0
column = 0
gs = gridspec.GridSpec(5, 2)
for label in df:
    fig = plt.figure()
    company = df[label]
    props = {
        'title': company.name
    }
    print(str(row) + ' - ' + str(column))
    plt.subplot()
    #     ax = plt.gca()
    #     ax.label = company.name
    plt.ylabel('Closing price')
    plt.xlabel(company.name)
    plt.plot(df.index.values, company)
    # company.plot(ax=ax, style='b-')
    # ax.set(**props)
    if column >= 1:
        column = 0
    else:
        column += 1

    if column == 0:
        row += 1
# Out:
# 0 - 0
# 0 - 1
# 1 - 0
# 1 - 1
# 2 - 0
# 2 - 1
# 3 - 0
# 3 - 1
# 4 - 0
# 4 - 1
# 5 - 0
# 5 - 1
# 6 - 0
# 6 - 1
# 7 - 0
# 7 - 1
# 8 - 0
# 8 - 1
# 9 - 0
# 9 - 1

# %% [markdown]
# # Normalizando os papéis
# Todas as cotações serão divididas pela cotação inicial para prover um ponto de início em comum

# %%
cm = plt.cm.get_cmap('tab20')
first_row = df.iloc[0]
ndf = df / first_row
ndf.plot(figsize=(15, 8), color=cm.colors)
plt.show()

# %%
percentages = [(24.0, 'MPLU3'), (7.0, 'EQTL3'), (6.0, 'ITSA3'), (6.0, 'BBDC4'), (5.0, 'ABCB4'), (5.0, 'FESA4'), (4.0, 'NATU3'), (4.0, 'FRAS3'), (4.0, 'UNIP3'), (4.0, 'ITUB3'), (4.0, 'TRPL4'), (4.0, 'SAPR4'), (4.0, 'ENBR3'), (3.0, 'EGIE3'), (3.0, 'RENT3'), (3.0, 'CMIG4'), (3.0, 'CSNA3'), (3.0, 'PCAR4'), (3.0, 'CYRE3'), (2.0, 'PTBL3')]

virtual_portfolio = df.copy()

for (weight, asset) in percentages:
    virtual_portfolio[asset] = virtual_portfolio[asset] * weight / 100.0

old_virtual_portfolio = np.sum(virtual_portfolio, axis=1)
plt.figure()
old_virtual_portfolio.plot()

plt.figure()
new_virtual_portfolio = np.mean(virtual_portfolio, axis=1) * 250
new_virtual_portfolio.plot()

annual_returns = np.mean(virtual_portfolio) * 250
print(annual_returns)
# Out:
# Sigla
# ABCB4     217.826149
# BBDC4     598.382759
# CMIG4      97.039655
# CSNA3      73.122414
# CYRE3     115.945690
# EGIE3     275.280517
# ENBR3     152.998851
# EQTL3    1339.272989
# FESA4     277.056034
# FRAS3      47.517241
# ITSA3     204.925862
# ITUB3     308.181207
# MPLU3    1522.979310
# NATU3     422.483908
# PCAR4     651.682759
# PTBL3      26.202874
# RENT3     223.371552
# SAPR4     117.594253
# TRPL4     720.413793
# UNIP3     373.290931
# dtype: float64

# %%
initial_value = old_virtual_portfolio.iloc[0]
current_value = old_virtual_portfolio.iloc[-1]
profit = current_value - initial_value

# %% [markdown]
# # Lucro nominal e percentual

# %%
print('Lucro nominal=%s; Lucro percentual=%s' % (profit, profit/initial_value))
# Out:
# Lucro nominal=6.367467999999995; Lucro percentual=0.2332787651839867
